# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

# %%
import sys
in_colab = 'google.colab' in sys.modules

if in_colab:
  BASE_DIR = "https://github.com/DiploDatos/AnalisisYCuracion/raw/master/"
else:
  BASE_DIR = ".."

# %%
tabla_1 = pd.read_csv(".." + "/input/wtageinf.csv")
tabla_1.head(10)
# Out:
#    Sex  Agemos         L         M         S        P3        P5       P10  \
# 0    1     0.0  1.815151  3.530203  0.152385  2.355451  2.526904  2.773802
# 1    1     0.5  1.547523  4.003106  0.146025  2.799549  2.964656  3.209510
# 2    1     1.5  1.068796  4.879525  0.136479  3.614688  3.774849  4.020561
# 3    1     2.5  0.695974  5.672889  0.129678  4.342341  4.503255  4.754479
# 4    1     3.5  0.419815  6.391392  0.124717  4.992898  5.157412  5.416803
# 5    1     4.5  0.219867  7.041836  0.121040  5.575169  5.744752  6.013716
# 6    1     5.5  0.077506  7.630425  0.118271  6.096775  6.272175  6.551379
# 7    1     6.5 -0.021908  8.162951  0.116154  6.564430  6.745993  7.035656
# 8    1     7.5 -0.089441  8.644832  0.114510  6.984123  7.171952  7.472021
# 9    1     8.5 -0.133409  9.081120  0.113217  7.361236  7.555287  7.865533
#
#         P25       P50       P75        P90        P95        P97
# 0  3.150611  3.530203  3.879077   4.172493   4.340293   4.446488
# ...

# %%
tabla_1.dtypes
# Out:
# Sex         int64
# Agemos    float64
# L         float64
# M         float64
# S         float64
# P3        float64
# P5        float64
# P10       float64
# P25       float64
# P50       float64
# P75       float64
# P90       float64
# P95       float64
# P97       float64
# dtype: object

# %%
tabla_1.columns
# Out:
# Index(['Sex', 'Agemos', 'L', 'M', 'S', 'P3', 'P5', 'P10', 'P25', 'P50', 'P75',
#        'P90', 'P95', 'P97'],
#       dtype='object')

# %%
filtrado= tabla_1[tabla_1.Sex==1]
filtrado.plot(x='Agemos', y='P3');

# %%
plt.figure(figsize=(10,12))
plt.plot('Agemos', 'P3', data=filtrado, label='P3');
plt.plot('Agemos', 'P5', data=filtrado, label='P5');
plt.plot('Agemos', 'P10', data=filtrado, label='P10');
plt.plot('Agemos', 'P25', data=filtrado, label='P25');
plt.plot('Agemos', 'P50', data=filtrado, label='P50');
plt.plot('Agemos', 'P75', data=filtrado, label='P75');
plt.plot('Agemos', 'P90', data=filtrado, label='P90');
plt.plot('Agemos', 'P95', data=filtrado, label='P95');
plt.plot('Agemos', 'P97', data=filtrado, label='P97');
#plt.legend();
plt.show();

# %%
fig, ax = plt.subplots(figsize=(10,12))

for cols in ['P3', 'P5', 'P10','P25', 'P50', 'P75','P90', 'P95', 'P97']:
    filtrado.plot('Agemos', cols, ax=ax)
